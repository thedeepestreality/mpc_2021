# %%
import numpy as np
import math
from scipy.integrate import odeint
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Здесь мы импортировали

# %%
a = 0.5
b = 0.1
kp = -12
ki = -4
x0 = np.array([1,0])
xd = 0.5
tt = np.arange(0,20.5,0.5)

def rp(in_,t):
    x = in_[0]
    ei = in_[1]
    ep = x-xd
    u = kp*ep + ki*ei
    dx = a*x + b*u
    return np.array([dx,ep])

X = odeint(rp,x0,tt)
plt.plot(tt,X[:,0])
plt.grid()
